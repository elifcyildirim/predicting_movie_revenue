# %%
import pandas as pd
import numpy as np
import re
import csv

from bs4 import BeautifulSoup
import requests
import time, os 
import random
from fake_useragent import UserAgent

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

ua = UserAgent()

# %%
movies = pd.read_csv('./movies_2021_2017.csv')

# %%
movies.shape
# Out:
# (4452, 12)

# %%
movies.tail()
# Out:
#       Unnamed: 0                                          title   movie_id  \
# 4447        4447  WHAT IF? A (Fan-Made) 'Life is Strange' Story  tt7732486
# 4448        4448                                  Created Equal  tt5873100
# 4449        4449                                Kate Can't Swim  tt5752904
# 4450        4450                                 Blue Hollywood  tt5588118
# 4451        4451                        A Closer Walk with Thee  tt4943620
#
#                                         movie_imdb_link certificate  \
# 4447  https://www.imdb.com/title/tt7732486/?ref_=adv...          []
# 4448  https://www.imdb.com/title/tt5873100/?ref_=adv...       TV-PG
# 4449  https://www.imdb.com/title/tt5752904/?ref_=adv...          []
# 4450  https://www.imdb.com/title/tt5588118/?ref_=adv...          []
# 4451  https://www.imdb.com/title/tt4943620/?ref_=adv...     Unrated
#
#      runtime_in_mins                   genre  imdb_rating  number_of_votes  \
# 4447             127          Drama, Mystery          5.1              204
# 4448              91         Drama, Thriller          5.5              204
# 4449              90                   Drama          5.5              201
# 4450              82  Comedy, Drama, Romance          7.3              200
# 4451              89           Drama, Horror          3.8              200
#
#      metascore      top_director  release_year
# 4447        []  See full summary          2017
# 4448        []         Bill Duke          2017
# 4449        []       Josh Helman          2017
# 4450        []  See full summary          2017
# 4451        []     John C. Clark          2017

# %%
movies = movies.drop(['Unnamed: 0'], axis=1) 
movies.head()
# Out:
#                           title    movie_id  \
# 0       Spider-Man: No Way Home  tt10872600
# 1                          Dune   tt1160419
# 2                 Don't Look Up  tt11286314
# 3                No Time to Die   tt2382320
# 4  Zack Snyder's Justice League  tt12361974
#
#                                      movie_imdb_link certificate  \
# 0  https://www.imdb.com/title/tt10872600/?ref_=ad...       PG-13
# 1  https://www.imdb.com/title/tt1160419/?ref_=adv...       PG-13
# 2  https://www.imdb.com/title/tt11286314/?ref_=ad...           R
# 3  https://www.imdb.com/title/tt2382320/?ref_=adv...       PG-13
# 4  https://www.imdb.com/title/tt12361974/?ref_=ad...           R
#
#   runtime_in_mins                        genre  imdb_rating  number_of_votes  \
# 0             148   Action, Adventure, Fantasy          8.3           739086
# 1             155     Action, Adventure, Drama          8.0           621069
# 2             138        Comedy, Drama, Sci-Fi          7.2           529981
# 3             163  Action, Adventure, Thriller          7.3           393930
# 4             242   Action, Adventure, Fantasy          8.0           393504
#
#   metascore        top_director  release_year
# 0        71           Jon Watts          2021
# 1        74    Denis Villeneuve          2021
# 2        49          Adam McKay          2021
# 3        68  Cary Joji Fukunaga          2021
# 4        54         Zack Snyder          2021

# %%
def scrape_movie_details(df):
    
    movies_details_dict = {}  #initializing an empty dictionary to fill with information
    
    for i in df.index:
        title = df['title'][i]
        movie_id = df['movie_id'][i]
        movie_imdb_link = df['movie_imdb_link'][i]

        user_agent = {'User-agent': ua.random} # generates a random user agent.
        response = requests.get(movie_imdb_link,headers = user_agent).text
        soup = BeautifulSoup(response, "html.parser")
    
        #top writer
        try:
            top_writer = soup.select('div.sc-fa02f843-2.dwQKsL > div > div > ul > li:nth-child(2) > div > ul > li:nth-child(1) > a')[0].get_text()
        except:
            top_writer = []
    
        # top listed three actors/actresses 

        #star #1
        try:
            top_star_1 = soup.select('div.sc-fa02f843-2.dwQKsL > div > div > ul > li:nth-child(3) > div > ul > li:nth-child(1) > a')[0].get_text()
        except:
            top_star_1 = []
        
        # star #2
        try:
            top_star_2 = soup.select('div.sc-fa02f843-2.dwQKsL > div > div > ul > li:nth-child(3) > div > ul > li:nth-child(2) > a')[0].get_text()
        except:
            top_star_2 = []
        
        # star #3
        try:
            top_star_3 = soup.select('div.sc-fa02f843-2.dwQKsL > div > div > ul > li:nth-child(3) > div > ul > li:nth-child(3) > a')[0].get_text()
        except:
            top_star_3 = []
        
        # number of user reviews
        try:
            num_user_reviews = soup.find_all(class_="label")[0].findPrevious().text
        except:
            num_user_reviews = 0
        
        # number of critic reviews
        try:
            num_critic_reviews = soup.find(text=re.compile('Critic reviews')).findPrevious().findPrevious().text
        except:
            num_critic_reviews = 0
        
        # release date
        try:
            release_date = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(1) > div > ul > li > a')[0].get_text().split('(')[0].strip()
        except:
            release_date = []
        
        # release month
        try:
            release_month = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(1) > div > ul > li > a')[0].get_text().split('(')[0].strip().split(' ')[0].strip()
        except: 
            release_month = []
        
        # country of origin
        try:
            country_of_origin = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(2) > div > ul > li > a')[0].get_text()
        except:
            country_of_origin = []
        
        # top production company:
        try:
            top_production_company = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(7) > div > ul > li:nth-child(1) > a')[0].get_text()
        except:
            top_production_company = []
        
        # Budget in USD: Production budget refers to the cost to make the movie and it does not include marketing or other expenditures.
        try:
            budget_in_usd = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(1) > div > ul > li > span')[0].get_text().split('(')[0].strip().replace('$',"").replace(',','')
        except:
            budget_in_usd = []
        
        # Opening weekend US & Canada (in USD): Weekend box office charts show gross receipts for a given weekend, which is Friday through Sunday unless otherwise noted.
        try:
            opening_weekend_us_can_in_usd = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(3) > div > ul > li:nth-child(1) > span')[0].get_text().replace('$',"").replace(',','')
        except: 
            opening_weekend_us_can_in_usd = []
        
        # Gross US & Canada in USD (Gross refers to gross earnings in U.S. dollars.)
        try:
            gross_us_can_in_usd = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(2) > div > ul > li > span')[0].get_text().replace('$',"").replace(',','')
        except:
            gross_us_can_in_usd = []
        
        # Gross worldwide in USD
        try: 
            gross_worldwide_in_usd = soup.select('div.sc-f65f65be-0.ktSkVi > ul > li:nth-child(4) > div > ul > li > span')[0].get_text().replace('$',"").replace(',','')
        except:
            gross_worldwide_in_usd = []
        
        movies_details_dict[df.index[i]] = [title]+[movie_id]+[movie_imdb_link]+[top_writer]+[top_star_1]+[top_star_2]+\
        [top_star_3]+[num_user_reviews]+[num_critic_reviews]+[release_date]+[release_month]+[country_of_origin]+\
        [top_production_company]+[budget_in_usd]+[opening_weekend_us_can_in_usd]+[gross_us_can_in_usd]+\
        [gross_worldwide_in_usd]
    
        time.sleep(.5+2*random.random()) # random time between requests.

    # define headers
    headers = ['title','movie_id','movie_imdb_link', 'top_writer','top_star_1','top_star_2','top_star_3',
                  'num_user_reviews', 'num_critic_reviews', 'release_date','release_month','country_of_origin',
                  'top_production_company','budget_in_usd', 'opening_weekend_us_can_in_usd','gross_us_can_in_usd',
                  'gross_worldwide_in_usd' ]
    
    # turn into a dataframe    
    movie_details_dataframe = pd.DataFrame(movies_details_dict).T
    movie_details_dataframe.columns = headers
    
    #save the dataframe
    #movie_details_dataframe.to_csv('movie_details_2022.csv') # CHANGE THE YEAR ACC TO YOUR INTEREST
    
    return movie_details_dataframe

# %%
movie_details = scrap_movie_details(movies)

# %%
movie_details.shape
# Out:
# (4452, 17)

# %%
movie_details.head(10)
# Out:
#                                        title    movie_id  \
# 0                    Spider-Man: No Way Home  tt10872600
# 1                                       Dune   tt1160419
# 2                              Don't Look Up  tt11286314
# 3                             No Time to Die   tt2382320
# 4               Zack Snyder's Justice League  tt12361974
# 5  Shang-Chi and the Legend of the Ten Rings   tt9376612
# 6                                Black Widow   tt3480822
# 7                                   Free Guy   tt6264654
# 8                          The Suicide Squad   tt6334354
# 9                                   Eternals   tt9032400
#
#                                      movie_imdb_link      top_writer  \
# 0  https://www.imdb.com/title/tt10872600/?ref_=ad...   Chris McKenna
# 1  https://www.imdb.com/title/tt1160419/?ref_=adv...     Jon Spaihts
# 2  https://www.imdb.com/title/tt11286314/?ref_=ad...      Adam McKay
# 3  https://www.imdb.com/title/tt2382320/?ref_=adv...     Neal Purvis
# 4  https://www.imdb.com/title/tt12361974/?ref_=ad...    Jerry Siegel
# 5  https://www.imdb.com/title/tt9376612/?ref_=adv...   Dave Callaham
# 6  https://www.imdb.com/title/tt3480822/?ref_=adv...    Eric Pearson
# 7  https://www.imdb.com/title/tt6264654/?ref_=adv...  Matt Lieberman
# 8  https://www.imdb.com/title/tt6334354/?ref_=adv...      James Gunn
# 9  https://www.imdb.com/title/tt9032400/?ref_=adv...      Chloé Zhao
#
#            top_star_1         top_star_2            top_star_3  \
# 0         Tom Holland            Zendaya  Benedict Cumberbatch
# 1   Timothée Chalamet   Rebecca Ferguson               Zendaya
# 2   Leonardo DiCaprio  Jennifer Lawrence          Meryl Streep
# 3        Daniel Craig       Ana de Armas            Rami Malek
# 4        Henry Cavill        Ben Affleck             Gal Gadot
# 5            Simu Liu          Awkwafina   Tony Chiu-Wai Leung
# 6  Scarlett Johansson      Florence Pugh         David Harbour
# 7       Ryan Reynolds        Jodie Comer         Taika Waititi
# 8       Margot Robbie         Idris Elba             John Cena
# 9          Gemma Chan     Richard Madden        Angelina Jolie
#
#   num_user_reviews num_critic_reviews       release_date release_month  \
# 0             6.1K                412  December 17, 2021      December
# 1             5.6K                509   October 22, 2021       October
# 2             4.6K                309  December 24, 2021      December
# 3             4.1K                449    October 8, 2021       October
# 4               8K                308     March 18, 2021         March
# 5             2.4K                338  September 3, 2021     September
# 6             3.1K                390       July 9, 2021          July
# 7             2.1K                287    August 13, 2021        August
# 8             3.4K                378     August 5, 2021        August
# 9             3.6K                348   November 5, 2021      November
#
#   country_of_origin     top_production_company budget_in_usd  \
# 0     United States          Columbia Pictures     200000000
# 1            Canada               Warner Bros.     165000000
# 2     United States     Hyperobject Industries      75000000
# 3    United Kingdom  Metro-Goldwyn-Mayer (MGM)     250000000
# 4     United States        Atlas Entertainment     300000000
# 5     United States       Walt Disney Pictures     200000000
# 6     United States             Marvel Studios     200000000
# 7     United States       20th Century Studios     120000000
# 8     United States               Warner Bros.     185000000
# 9     United States             Marvel Studios     200000000
#
#   opening_weekend_us_can_in_usd gross_us_can_in_usd gross_worldwide_in_usd
# 0                     260138569           814115070             1916278650
# 1                      41011174           108327830              401847900
# 2                            []              791863               2.39 : 1
# 3                      55225007           160891007              774153007
# 4                            []                  []               1.33 : 1
# 5                      75388688           224543292              432243292
# 6                      80366312           183651655              379751655
# 7                      28365416           121626598              331526598
# 8                      26205415            55817425              168657565
# 9                      71297219           164870234              402064899

# %% [markdown]
# # Repeating everything for another dataframe

# %%
movies_2016_2015 = pd.read_csv('./movies_2016_2015.csv')

# %%
movies_2016_2015 = movies_2016_2015.drop(['Unnamed: 0'], axis=1) 
movies_2016_2015.head()
# Out:
#                                         title   movie_id  \
# 0  Star Wars: Episode VII - The Force Awakens  tt2488496
# 1                     Avengers: Age of Ultron  tt2395427
# 2                                 The Martian  tt3659388
# 3                                The Revenant  tt1663202
# 4                                  Inside Out  tt2096673
#
#                                      movie_imdb_link certificate  \
# 0  https://www.imdb.com/title/tt2488496/?ref_=adv...       PG-13
# 1  https://www.imdb.com/title/tt2395427/?ref_=adv...       PG-13
# 2  https://www.imdb.com/title/tt3659388/?ref_=adv...       PG-13
# 3  https://www.imdb.com/title/tt1663202/?ref_=adv...           R
# 4  https://www.imdb.com/title/tt2096673/?ref_=adv...          PG
#
#   runtime_in_mins                         genre  imdb_rating  number_of_votes  \
# 0             138     Action, Adventure, Sci-Fi          7.8           926911
# 1             141     Action, Adventure, Sci-Fi          7.3           858022
# 2             144      Adventure, Drama, Sci-Fi          8.0           848340
# 3             156      Action, Adventure, Drama          8.0           798584
# 4              95  Animation, Adventure, Comedy          8.2           708522
#
#   metascore           top_director  release_year
# 0        80            J.J. Abrams          2015
# 1        66            Joss Whedon          2015
# 2        80           Ridley Scott          2015
# 3        76  Alejandro G. Iñárritu          2015
# 4        94            Pete Docter          2015

# %%
movie_details_2016_2015 = scrape_movie_details(movies_2016_2015)

# %%
movie_details_2016_2015.head(3)
# Out:
#                                         title   movie_id  \
# 0  Star Wars: Episode VII - The Force Awakens  tt2488496
# 1                     Avengers: Age of Ultron  tt2395427
# 2                                 The Martian  tt3659388
#
#                                      movie_imdb_link       top_writer  \
# 0  https://www.imdb.com/title/tt2488496/?ref_=adv...  Lawrence Kasdan
# 1  https://www.imdb.com/title/tt2395427/?ref_=adv...      Joss Whedon
# 2  https://www.imdb.com/title/tt3659388/?ref_=adv...     Drew Goddard
#
#           top_star_1        top_star_2    top_star_3 num_user_reviews  \
# 0       Daisy Ridley       John Boyega   Oscar Isaac               5K
# 1  Robert Downey Jr.       Chris Evans  Mark Ruffalo             1.4K
# 2         Matt Damon  Jessica Chastain  Kristen Wiig             1.4K
#
#   num_critic_reviews       release_date release_month country_of_origin  \
# 0                913  December 18, 2015      December     United States
# 1                704        May 1, 2015           May     United States
# 2                642    October 2, 2015       October     United States
#
#   top_production_company budget_in_usd opening_weekend_us_can_in_usd  \
# 0              Lucasfilm     245000000                     247966675
# 1         Marvel Studios     250000000                     191271109
# 2  Twentieth Century Fox     108000000                      54308575
#
#   gross_us_can_in_usd gross_worldwide_in_usd
# 0           936662225             2069521700
# 1           459005868             1402809540
# 2           228433663              630620818

# %% [markdown]
# # Validation data (year 2022)

# %%
movies_2022 = pd.read_csv('./movies_2022.csv')

# %%
movies_2022.head()
# Out:
#                                     Unnamed: 0    movie_id  \
# 0                                   The Batman   tt1877830
# 1                            Top Gun: Maverick   tt1745960
# 2  Doctor Strange in the Multiverse of Madness   tt9419884
# 3                       Thor: Love and Thunder  tt10648342
# 4            Everything Everywhere All at Once   tt6710474
#
#                                      movie_imdb_link certificate  \
# 0  https://www.imdb.com/title/tt1877830/?ref_=adv...       PG-13
# 1  https://www.imdb.com/title/tt1745960/?ref_=adv...       PG-13
# 2  https://www.imdb.com/title/tt9419884/?ref_=adv...       PG-13
# 3  https://www.imdb.com/title/tt10648342/?ref_=ad...       PG-13
# 4  https://www.imdb.com/title/tt6710474/?ref_=adv...           R
#
#   runtime_in_mins                       genre  imdb_rating  number_of_votes  \
# 0             176        Action, Crime, Drama          7.9         613958.0
# 1             130               Action, Drama          8.4         413022.0
# 2             126  Action, Adventure, Fantasy          6.9         398982.0
# 3             118   Action, Adventure, Comedy          6.4         296865.0
# 4             139   Action, Adventure, Comedy          8.1         228555.0
#
#   metascore     top_director  release_year
# 0        72      Matt Reeves          2022
# 1        78  Joseph Kosinski          2022
# 2        60        Sam Raimi          2022
# 3        57    Taika Waititi          2022
# 4        81         Dan Kwan          2022

# %%
movies_2022 = movies_2022.reset_index(drop=True)
movies_2022 = movies_2022.rename(columns = {'Unnamed: 0':'title'})
movies_2022.head()
# Out:
#                                          title    movie_id  \
# 0                                   The Batman   tt1877830
# 1                            Top Gun: Maverick   tt1745960
# 2  Doctor Strange in the Multiverse of Madness   tt9419884
# 3                       Thor: Love and Thunder  tt10648342
# 4            Everything Everywhere All at Once   tt6710474
#
#                                      movie_imdb_link certificate  \
# 0  https://www.imdb.com/title/tt1877830/?ref_=adv...       PG-13
# 1  https://www.imdb.com/title/tt1745960/?ref_=adv...       PG-13
# 2  https://www.imdb.com/title/tt9419884/?ref_=adv...       PG-13
# 3  https://www.imdb.com/title/tt10648342/?ref_=ad...       PG-13
# 4  https://www.imdb.com/title/tt6710474/?ref_=adv...           R
#
#   runtime_in_mins                       genre  imdb_rating  number_of_votes  \
# 0             176        Action, Crime, Drama          7.9         613958.0
# 1             130               Action, Drama          8.4         413022.0
# 2             126  Action, Adventure, Fantasy          6.9         398982.0
# 3             118   Action, Adventure, Comedy          6.4         296865.0
# 4             139   Action, Adventure, Comedy          8.1         228555.0
#
#   metascore     top_director  release_year
# 0        72      Matt Reeves          2022
# 1        78  Joseph Kosinski          2022
# 2        60        Sam Raimi          2022
# 3        57    Taika Waititi          2022
# 4        81         Dan Kwan          2022

# %%
movie_details_2022 = scrape_movie_details(movies_2022)

# %%
movie_details_2022.head(3)
# Out:
#                                          title   movie_id  \
# 0                                   The Batman  tt1877830
# 1                            Top Gun: Maverick  tt1745960
# 2  Doctor Strange in the Multiverse of Madness  tt9419884
#
#                                      movie_imdb_link       top_writer  \
# 0  https://www.imdb.com/title/tt1877830/?ref_=adv...      Matt Reeves
# 1  https://www.imdb.com/title/tt1745960/?ref_=adv...         Jim Cash
# 2  https://www.imdb.com/title/tt9419884/?ref_=adv...  Michael Waldron
#
#              top_star_1         top_star_2        top_star_3 num_user_reviews  \
# 0      Robert Pattinson        Zoë Kravitz    Jeffrey Wright             7.7K
# 1            Tom Cruise  Jennifer Connelly      Miles Teller             3.7K
# 2  Benedict Cumberbatch    Elizabeth Olsen  Chiwetel Ejiofor             3.9K
#
#   num_critic_reviews   release_date release_month country_of_origin  \
# 0                520  March 4, 2022         March     United States
# 1                386   May 27, 2022           May     United States
# 2                399    May 6, 2022           May     United States
#
#   top_production_company budget_in_usd opening_weekend_us_can_in_usd  \
# 0           Warner Bros.     200000000                     134008624
# 1     Paramount Pictures     170000000                     126707459
# 2         Marvel Studios     200000000                     187420998
#
#   gross_us_can_in_usd gross_worldwide_in_usd
# 0           369345583              770836163
# 1           716657763             1485757763
# 2           411331607              955775804

# %%
movie_details_2022.shape
# Out:
# (477, 17)
